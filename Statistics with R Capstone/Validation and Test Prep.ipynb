# %%
import pandas as pd

# %%
df = pd.read_csv("amestest.csv")

# %%
df
# Out:
#            PID  area   price  MS.SubClass MS.Zoning  Lot.Frontage  Lot.Area  \
# 0    907250050  2000  305900           20        RL          80.0     10386
# 1    909425140  1839  257500           20        RL         110.0     14442
# 2    535301080   882  116000           20        RL          60.0     11556
# 3    534125120  1152  143450           20        RL          78.0     11700
# 4    528186090  1561  277500          120        RL          60.0      7313
# ..         ...   ...     ...          ...       ...           ...       ...
# 812  907290170   848  143750          120        RM           NaN      4435
# 813  903476100   840   87000           45        RM          55.0      4388
# 814  527212060  2541  349265           60        RL          98.0     12328
# 815  534126090  1682  174000           20        RL          80.0     10400
# 816  909276070  1717  194000           50        RL          80.0     12400
#
# ...

# %%
df["Age"] = 2021 - df["Year.Built"]

# %%
df.head()
# Out:
#          PID  area   price  MS.SubClass MS.Zoning  Lot.Frontage  Lot.Area  \
# 0  907250050  2000  305900           20        RL          80.0     10386
# 1  909425140  1839  257500           20        RL         110.0     14442
# 2  535301080   882  116000           20        RL          60.0     11556
# 3  534125120  1152  143450           20        RL          78.0     11700
# 4  528186090  1561  277500          120        RL          60.0      7313
#
#   Street Alley Lot.Shape  ... Pool.Area Pool.QC  Fence Misc.Feature Misc.Val  \
# 0   Pave   NaN       Reg  ...         0     NaN    NaN          NaN        0
# 1   Pave   NaN       Reg  ...         0     NaN    NaN          NaN        0
# 2   Pave   NaN       Reg  ...         0     NaN  MnPrv          NaN        0
# 3   Pave   NaN       Reg  ...         0     NaN    NaN          NaN        0
# 4   Pave   NaN       Reg  ...         0     NaN    NaN          NaN        0
#
#   Mo.Sold Yr.Sold Sale.Type Sale.Condition  Age
# ...

# %%
df2 = df[['Age', 'Lot.Area', 'Total.Bsmt.SF', 'X1st.Flr.SF', 'Garage.Cars', 'Garage.Area', 
        'TotRms.AbvGrd', 'Full.Bath', 'Fireplaces', 'Overall.Qual','price']]

# %%
df2
# Out:
#      Age  Lot.Area  Total.Bsmt.SF  X1st.Flr.SF  Garage.Cars  Garage.Area  \
# 0     17     10386           2000         2000            3          888
# 1     64     14442           1477         1839            2          416
# 2     69     11556            720          882            1          240
# 3     53     11700            912         1152            2          412
# 4     16      7313           1561         1561            2          556
# ..   ...       ...            ...          ...          ...          ...
# 812   18      4435            848          848            2          420
# 813   91      4388            672          840            0            0
# 814   16     12328           1149         1164            3          729
# 815   51     10400           1304         1682            2          530
# 816   81     12400            901         1125            1          410
#
#      TotRms.AbvGrd  Full.Bath  Fireplaces  Overall.Qual   price
# ...

# %%
#df2.to_csv("test.csv",index=False)

# %%
df3 = pd.read_csv("amesvalid.csv")

# %%
df3.head()
# Out:
#          PID  area   price  MS.SubClass MS.Zoning  Lot.Frontage  Lot.Area  \
# 0  909276070  1717  194000           50        RL          80.0     12400
# 1  534278190   894  117600           20        RL          70.0      8680
# 2  534204120  1073  156000           20        RL          79.0     10289
# 3  535425040  1773  183000           20        RL          80.0     10800
# 4  907202160  1026  147000           80        RL           NaN     10970
#
#   Street Alley Lot.Shape  ... Screen.Porch Pool.Area Pool.QC  Fence  \
# 0   Pave   NaN       Reg  ...          113         0     NaN    NaN
# 1   Pave   NaN       Reg  ...            0         0     NaN    NaN
# 2   Pave   NaN       Reg  ...            0         0     NaN    NaN
# 3   Pave   NaN       Reg  ...          144         0     NaN    NaN
# 4   Pave   NaN       IR1  ...            0         0     NaN  MnPrv
#
#   Misc.Feature Misc.Val Mo.Sold Yr.Sold Sale.Type  Sale.Condition
# ...

# %%
df3["Age"] = 2021 - df3["Year.Built"]

# %%
df4 = df3[['Age', 'Lot.Area', 'Total.Bsmt.SF', 'X1st.Flr.SF', 'Garage.Area', 
        'TotRms.AbvGrd', 'Fireplaces', 'Overall.Qual','price']]

# %%
df4.head()
# Out:
#    Age  Lot.Area  Total.Bsmt.SF  X1st.Flr.SF  Garage.Area  TotRms.AbvGrd  \
# 0   81     12400            901         1125          410              7
# 1   61      8680            894          894          312              5
# 2   56     10289           1073         1073          515              6
# 3   60     10800           1313         1773          418              6
# 4   43     10970            940         1026          576              5
#
#    Fireplaces  Overall.Qual   price
# 0           1             5  194000
# 1           0             5  117600
# 2           0             5  156000
# 3           2             6  183000
# 4           0             6  147000

# %%
#df4.to_csv("valid.csv",index=False)
